# %% [markdown]
# ## Note
# forcing_upset comes from the VENN analysis of the features based on the combined cluster-clade variable. There were too many combinations to show in a venn diagram, so this approach was taken

# %%
data<-read.csv('forcing_upset.csv')
data
# Out:
#    name        total nameii
# 1  x-6          228  6-x
# 2  v-4          261  4-v
# 3  v-5          271  5-v
# 4  u-2          510  2-u
# 5  w-2          877  2-w
# 6  y-3          896  3-y
# 7  u-1         2633  1-u
# 8  u-1 y-3      225  1-u 3-y
# 9  u-1 w-2      451  1-u 2-w
# 10 u-1 u-2     1117  1-u 2-u
# 11 u-1 u-2 w-2  423  1-u 2-u 2-w
# 12 All          500  All

# %%
counts<-data$total
counts
names<-data$nameii
names
# Out:
#  [1]  228  261  271  510  877  896 2633  225  451 1117  423  500
#  [1] "6-x"         "4-v"         "5-v"         "2-u"         "2-w"
#  [6] "3-y"         "1-u"         "1-u 3-y"     "1-u 2-w"     "1-u 2-u"
# [11] "1-u 2-u 2-w" "All"

# %%
barplot(counts, names.arg=names, 
        las=2,
       #xlab = "cluster-clade combination",
        ylab = "features",
        axes=T
       #horiz = TRUE
       
       )
# Out:
# plot without title
